# %%
import pandas as pd

# %%
# Load csv file with all the data
df = pd.read_csv("joined_data.csv")

# %%
df.head()
# Out:
#   csv_index                                          file_name  \
# 0       1.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
# 1       1.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
# 2       1.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
# 3       1.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
# 4       1.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
#
#      mouse1_topleft_x  mouse1_topleft_y  mouse1_rightdown_x  \
# 0    309.819096782505        182.136622          402.420489
# 1  348.03769787812223        100.164178          420.483310
# 2  117.38233841437452         34.027243          373.146047
# 3  169.09538588003477        180.972369          368.286246
# 4  233.39919271055095        213.434775          533.426048
#
#    mouse1_rightdown_y  mouse1_nose_x  mouse1_nose_y  mouse1_leftear_x  \
# 0          240.139692     316.340104     208.188458        327.316715
# 1          234.093237     379.494345     110.649727        365.672485
# ...
