# %%
import pandas as pd
import numpy as np

# %%
# Load the data
df = pd.read_csv("raw_data/A20521480_CollectedData_annotation.csv")

# %%
df.head()
# Out:
#         scorer  Unnamed: 1                                         Unnamed: 2  \
# 0  individuals         NaN                                                NaN
# 1    bodyparts         NaN                                                NaN
# 2       coords         NaN                                                NaN
# 3        CS584        34.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
# 4        CS584        34.0  A_male_in_a_new_cage_face_view_3_2022-08-10_15...
#
#            annotation        annotation.1      annotation.2  \
# 0              mouse1              mouse1            mouse1
# 1             topleft             topleft         rightdown
# 2                   x                   y                 x
# 3  209.42088249551279  122.80925279960982   327.20554145475
# 4  201.71534405892717  154.73219775117894  363.531651227225
#
#          annotation.3        annotation.4        annotation.5  \
# 0              mouse1              mouse1              mouse1
# ...

# %%
print(df.shape[1])
# Out:
# 39

# %%
columns = np.empty(df.shape[1])
for i in range(3):
    columns += df.iloc[i,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/roperator.py:11, in radd(left, right)
# ...
